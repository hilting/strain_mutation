# %%
import pandas as pd

# %%
pd.set_option("display.max_rows", 1000)

# %%
strains = ("TriTrypDB-35_TcruziCLBrenerEsmeraldo-like_AnnotatedProteins.fasta2.csv",
           "TriTrypDB-35_TcruziCLBrenerNon-Esmeraldo-like_AnnotatedProteins.fasta2.csv",
           "TriTrypDB-35_TcruziDm28c_AnnotatedProteins.fasta2.csv"
          )

# %%
dm28 = pd.read_csv(strains[2])

# %%
dm28["bitscore"] = dm28["bitscore"].astype("int")

# %%
dm_s_max = dm28.loc[dm28.groupby("qseqid")["bitscore"].idxmax()]

# %%
dm_s_max[dm_s_max["pident"] > 50]
# Out:
#                      qseqid                                      sseqid  \
# 10      TCDM_00002-t26_1-p1                     TcCLB.506887.20:mRNA-p1
# 12      TCDM_00003-t26_1-p1                     TcCLB.506887.40:mRNA-p1
# 20      TCDM_00004-t26_1-p1                     TcCLB.506887.50:mRNA-p1
# 175     TCDM_00005-t26_1-p1                     TcCLB.506887.60:mRNA-p1
# 179     TCDM_00007-t26_1-p1                     TcCLB.506887.69:mRNA-p1
# 205     TCDM_00009-t26_1-p1                     TcCLB.506887.90:mRNA-p1
# 256     TCDM_00010-t26_1-p1                    TcCLB.506887.100:mRNA-p1
# 353     TCDM_00011-t26_1-p1  TcCLB.506887.110:pseudogenic_transcript-p1
# 362     TCDM_00012-t26_1-p1                     TcCLB.503669.39:mRNA-p1
# 370     TCDM_00013-t26_1-p1                     TcCLB.503669.30:mRNA-p1
# 377     TCDM_00014-t26_1-p1                     TcCLB.503669.20:mRNA-p1
# 387     TCDM_00015-t26_1-p1                     TcCLB.503669.10:mRNA-p1
# ...
